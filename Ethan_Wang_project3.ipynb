# %% [markdown]
# # Project 3 -- [Ethan] [Wang]

# %% [markdown]
# **TA Help:** No One
#
# -
#
# **Collaboration:** No One
#
# -

# %% [markdown]
# ## Question 1

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/flights/subset/1990.csv")
# Sums up the ArrDelay column before grouping by Dest column and removes all of the NA values
tapply(myDF$ArrDelay, myDF$Dest, sum, na.rm=TRUE)
# Out:
#     ABE     ABQ     ACY     AGS     ALB     AMA     ANC     ATL     ATW     AUS
#   27857  242992    4124   25468   99727   52993  160334 2302776   -2802  172232
#     AVL     AVP     AZO     BDL     BET     BFL     BGM     BGR     BHM     BIL
#   12531   21920   10883  215093    6727    9477    9301   27782   99684   22818
#     BIS     BLI     BNA     BOI     BOS     BTM     BTR     BTV     BUF     BUR
#   16416   12013  159653   49489  797212    4223   65329   49237  192876   75365
#     BWI     BZN     CAE     CAK     CCR     CDV     CHA     CHO     CHS     CID
#  418219   23150   94275   20525    1342    5629   24160    2158   82481   36123
#     CLE     CLT     CMH     CMI     COS     CPR     CRP     CRW     CSG     CVG
#  453217  536578  179847    4337   64095    2330   50331   12603    9663  437204
#     DAB     DAL     DAY     DCA     DEN     DET     DFW     DLH     DRO     DSM
#   64636  249348  151141  422779 1121578   45381 1908596    3514    8325   76504
# ...

# %% [markdown]
# Through the tapply function you are able to specify which columns you would like to perform a specific action. For example, we are applying to the ArrDelay column the mean function which will average the ArrDelay and group them according to the Dest column. I was also able to remove the missing data by adding na.rm=TRUE which left only the data that did have values.

# %% [markdown]
# ## Question 2

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")
# Sums up the SPEND column before grouping by STORE_R column
tapply(myDF$SPEND, myDF$STORE_R, sum)
# Out:
#  CENTRAL     EAST    SOUTH     WEST
#  8897305 11699447  7957921  9680107

# %% [markdown]
# In this example, we are applying to the SPEND column the sum function which will add up the SPEND column and group them according to the STORE_R column.

# %% [markdown]
# ## Question 3

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")
# Sums up the SPEND column 
# head(myDF) I used this to find out what was the column name
# tail(myDF)
tapply(myDF$SPEND, myDF$YEAR, sum, na.rm=TRUE)
# sum(myDF$SPEND, myDF$YEAR, na.rm=TRUE)
# sum(myDF$SPEND, na.rm=TRUE)[grep("2017", myDF$YEAR)]
# Out:
#     2016     2017
# 19051720 19183059

# %% [markdown]
# In this example, we are applying to the SPEND column the sum function which will add up the SPEND column and remove all of the NA values. While doing this the grep value will pull all of the 2016 and 2017 values

# %% [markdown]
# ## Question 4

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/olympics/athlete_events.csv")
# head(myDF) I used this to find out what was the column name
# Sums up the Height column before grouping by NOC column and removes all of the NA values
tapply(myDF$Height, myDF$NOC, sum, na.rm=TRUE)
# Out:
#     AFG     AHO     ALB     ALG     AND     ANG     ANT     ANZ     ARG     ARM
#    9212    9042    9861   85255   23450   43660   20139    4595  403895   35935
#     ARU     ASA     AUS     AUT     AZE     BAH     BAN     BAR     BDI     BEL
#    7102    3689 1191954  575742   47670   62814    7977   33907    6560  316177
#     BEN     BER     BHU     BIH     BIZ     BLR     BOH     BOL     BOT     BRA
#   10421   24482    4829   20007   12779  297630    1044   19699   14768  597749
#     BRN     BRU     BUL     BUR     CAF     CAM     CAN     CAY     CGO     CHA
#   18383    1495  523332    6512    8426    9503 1422227   13104   14316    6003
#     CHI     CHN     CIV     CMR     COD     COK     COL     COM     CPV     CRC
#   94143  843337   28050   45145   11749    6339  166347    2563    3166   36604
#     CRO     CRT     CUB     CYP     CZE     DEN     DJI     DMA     DOM     ECU
#  153317       0  386897   33745  333355  323637    5376    3148   36510   44326
# ...

# %% [markdown]
# In this example, we are applying to the Height column the sum function which will add up the Height column and group them according to the NOC column. While doing this, the na.rm=TRUE will remove all of the values that do not have a sum.

# %% [markdown]
# ## Question 5

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/olympics/athlete_events.csv")
# head(myDF) to find out the names of the columns
# Averages the values in the Height column before grouping by Sport column and then removes the NA values
# Sorts the remaining values by decreasing order
sort(tapply(myDF$Height, myDF$Sport, mean, na.rm=TRUE), decreasing=TRUE)
# Out:
#                Basketball                Volleyball          Beach Volleyball
#                  190.8699                  186.9948                  186.1450
#                Water Polo                    Rowing                  Handball
#                  184.8346                  184.1722                  183.3846
#                  Baseball                Tug-Of-War                 Bobsleigh
#                  182.5993                  182.4800                  181.4375
#              Motorboating                Ice Hockey                    Tennis
#                  181.0000                  178.9013                  178.8981
#                  Swimming                  Canoeing              Jeu De Paume
#                  178.5625                  178.5396                  178.5000
#                   Sailing         Modern Pentathlon                   Fencing
#                  178.2622                  177.9443                  177.1642
# ...

# %% [markdown]
# Here we are using a combination of the tapply function and the sort function. The tapply method will average the Height column and group them according to the Sport column. Then, the sort column will then sort the values by decreasing order.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
