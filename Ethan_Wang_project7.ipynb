# %% [markdown]
# # Project 7 -- [Ethan] [Wang]

# %% [markdown]
# **TA Help:** NA
#
# - NA
#
# **Collaboration:** NA
#
# - NA

# %% [markdown]
# ## Question 1

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/death_records/DeathRecords.csv")
# Creates 5 categories and sort the ages into the five categories 
table(cut(myDF$Age, breaks = c(-Inf, 18, 25, 35, 55, 150, Inf)))
table(cut(myDF$Age, breaks = c(-Inf, 18, 25, 35, 55, 150, Inf), labels = c("youth", "young adult", "adult", "middle age adult", "senior adult", "unknown")))
# Out:
#  (-Inf,18]    (18,25]    (25,35]    (35,55]   (55,150] (150, Inf]
#      36033      27691      49540     271181    2246155        571
#            youth      young adult            adult middle age adult
#            36033            27691            49540           271181
#     senior adult          unknown
#          2246155              571

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/death_records/DeathRecords.csv")
# Creates 5 categories and sort the ages into the five categories 
age_categories <- cut(myDF$Age,breaks = c(-Inf, 18, 25, 35, 55, Inf), labels = c("youth", "young adult", "adult", "middle age adult", "senior adult"))

# Creates a table of the age categories
age_table <- table(age_categories)

# Counts unknown ages 
age_table_with_na <- table(age_categories, useNA = "always")

# Adds labels to the categories
age_table_labeled <- table(age_categories, useNA = "always")

# Creates a barplot for the distribution of age categories
barplot(age_table_with_na, main="Distribution of Age Categories", ylab="Number of People", xlab="Age Categories")
# Out:
# Plot with title "Distribution of Age Categories"

# %% [markdown]
# Using the data.table package in R we were able to read the CSV file. We then use the fread function to read in the csv file. With cut we were able to categorize the data and handle values that were unknown with the parameter <useNA="always">. The barplot funciton allowed us to visualize and understand the distribution of age categories

# %% [markdown]
# ## Question 2

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")
# Sums up the columns SPEND by YEAR and STORE_R
tapply(myDF$SPEND, list(myDF$YEAR, myDF$STORE_R), sum, na.rm = TRUE)
# Out:
#      CENTRAL EAST    SOUTH   WEST
# 2016 4471801 5829166 3996751 4754003
# 2017 4425505 5870281 3961170 4926104

# %% [markdown]
# Using the data.table package in R we were able to read the CSV file. We then use the fread function to read in the csv file. With the tapply function were able to summarize the data by multiple categories, thus it was easier to analyze and compare the spending across the different regions (central, east, south, west) and years (2016, 2017).

# %% [markdown]
# ## Question 3

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/beer/reviews_sample.csv")

# Converts the column of DATE to Date type
myDF$date <- as.Date(myDF$date)

# Takes out the Year and Month from DATE column
myDF$Year <- format(myDF$date, "%Y")
myDF$Month <- format(myDF$date, "%m")

# Calculates the average score by year and month
tapply(myDF$score, list(myDF$Year, myDF$Month), mean, na.rm = TRUE)
# Out:
#      01       02       03       04       05       06       07       08
# 1998 3.770000 3.396667 4.092000 3.840000 3.702000 4.700000 3.100000 3.823333
# 1999       NA 3.613333       NA       NA 3.820000 3.850000 3.880000       NA
# 2000       NA 4.300000       NA 3.880000       NA 4.470000 3.995000       NA
# 2001 4.220000 4.488000 4.403333 3.053333       NA 4.012000 4.080000 3.905455
# 2002 4.246667 3.706000 3.933846 3.831224 3.887788 3.782655 3.950776 3.628201
# 2003 3.842596 3.921875 3.840573 3.929500 3.895977 3.768022 3.742609 3.710635
# 2004 3.892104 3.822910 3.757987 3.825360 3.826656 3.798576 3.816569 3.861793
# 2005 3.872065 3.805870 3.884944 3.806607 3.743355 3.859615 3.769045 3.784184
# 2006 3.821626 3.789613 3.803201 3.833529 3.816436 3.847766 3.799106 3.795228
# 2007 3.796619 3.820563 3.785231 3.820230 3.768441 3.721336 3.809563 3.710408
# 2008 3.897296 3.879322 3.825841 3.866337 3.819464 3.824667 3.833681 3.845346
# ...

# %% [markdown]
# Using the data.table package in R we were able to read the CSV file. We then use the fread function to read in the csv file. We used tapply to combine and compute the average values over specific time intervals of months and years.

# %% [markdown]
# ## Question 4

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/election/itcont1980.txt", quote = "")
names(myDF) <- c("CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID")

# Creates a subset data for STATE == 'IN'
# Creates a table of donations by CITY before sorting it
# Shows the top 41 cities
head(sort(table(subset(myDF, STATE == "IN")$CITY), decreasing = TRUE), 41)
# Out:
#   INDIANAPOLIS         MUNCIE         CARMEL     FORT WAYNE     EVANSVILLE
#           1443            232            167            157            151
#        ELKHART       FT WAYNE         INDPLS     SOUTH BEND      LAFAYETTE
#            132            132            123            123             85
#    TERRE HAUTE        LAPORTE     ZIONSVILLE           GARY   MERRILLVILLE
#             75             53             52             47             46
#       COLUMBUS         KOKOMO       RICHMOND    BLOOMINGTON    CROWN POINT
#             45             45             43             38             35
#      GREENWOOD       ANDERSON     VALPARAISO         MUNICE        MUNSTER
#             35             34             34             31             30
#         WABASH       SYRACUSE WEST LAFAYETTE        HAMMOND    NOBLESVILLE
#             27             24             24             22             22
# ...

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/election/itcont1980.txt", quote = "")
names(myDF) <- c("CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID")

# Indexes the data instead of subset
indiana_donations_indexed <- myDF[myDF$STATE == "IN", ]

# Creates a table using the indexing before sorting it
city_table_indexed <- sort(table(indiana_donations_indexed$CITY))

# Displays the top 41 cities using indexing
print(city_table_indexed[1:41])
# Out:
#   INDIANAPOLIS         MUNCIE         CARMEL     FORT WAYNE     EVANSVILLE
#           1443            232            167            157            151
#        ELKHART       FT WAYNE         INDPLS     SOUTH BEND      LAFAYETTE
#            132            132            123            123             85
#    TERRE HAUTE        LAPORTE     ZIONSVILLE           GARY   MERRILLVILLE
#             75             53             52             47             46
#       COLUMBUS         KOKOMO       RICHMOND    BLOOMINGTON    CROWN POINT
#             45             45             43             38             35
#      GREENWOOD       ANDERSON     VALPARAISO         MUNICE        MUNSTER
#             35             34             34             31             30
#         WABASH       SYRACUSE WEST LAFAYETTE        HAMMOND    NOBLESVILLE
#             27             24             24             22             22
# ...

# %% [markdown]
# Using the data.table package in R we were able to read the CSV file. We then use the fread function to read in the csv file. Both the subset data and indexing strategies were used to create tables of the top 41 cities in Indiana according to donations from people in the city. One thing to notice that was strange was that there were multiple variations of the same city name like "INDIANAPOLIS" and "INDIANPOLIS" and "INDPLS".

# %% [markdown]
# ## Question 5

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/flights/subset/1990.csv")

# Classifies DepDelay values
delay_categories <- cut(myDF$DepDelay, breaks = c(-Inf, 0, 60, 120, 180, 240, 300, 1380, 1440), labels = c("Flight departed early or on time, i.e., DepDelay is negative or 0.", "Flight departed more than 0 but less than or equal to 60 minutes late.", "Flight departed more than 60 but less than or equal to 120 minutes late.", "Flight departed more than 120 but less than or equal to 180 minutes late.", "Flight departed more than 180 but less than or equal to 240 minutes late.", "Flight departed more than 240 but less than or equal to 300 minutes late.", "Flight departed more than 300 minutes late.", "Flight departed more than 1380 but less than or equal to 1440 minutes late."), dig.lab = 4)
# Creates a table of the delay categories with missing values
delay_table <- table(delay_categories, useNA = "always")

# Displays the delay table
print(delay_table)
# Out:
# delay_categories
#          Flight departed early or on time, i.e., DepDelay is negative or 0.
#                                                                     2966433
#      Flight departed more than 0 but less than or equal to 60 minutes late.
#                                                                     2111783
#    Flight departed more than 60 but less than or equal to 120 minutes late.
#                                                                      104240
#   Flight departed more than 120 but less than or equal to 180 minutes late.
#                                                                       24000
#   Flight departed more than 180 but less than or equal to 240 minutes late.
#                                                                        7517
#   Flight departed more than 240 but less than or equal to 300 minutes late.
#                                                                        2630
# ...

# %% [markdown]
# Using the data.table package in R we were able to read the CSV file. We then use the fread function to read in the csv file. Using the cut and table functions we were able to classify and count the number of flights based on delay durations.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
