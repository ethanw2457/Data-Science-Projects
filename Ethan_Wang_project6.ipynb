# %% [markdown]
# # Project 6 -- [Ethan] [Wang]

# %% [markdown]
# **TA Help:** NA
#
# - NA
#
# **Collaboration:** NA
#
# - NA

# %% [markdown]
# ## Question 1

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/death_records/DeathRecords.csv")
# Displays a table of all of the values of Race
table(myDF$Race)
# Filipino race corresponds to Race == 7
sum(myDF$Race == 7)
# Out:
#       1       2       3       4       5       6       7      18      28      38
# 2241510  309504   18031   13297    8159     700   11074    6778    4711     623
#      48      58      68      78
#    4913     316    8737    2818
# [1] 11074

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/death_records/DeathRecords.csv")
# Displays a table of all of the values of Race
table(myDF$Race)
# Filipino race corresponds to Race == 7
sum(myDF$Race == 7)
# plots a table of which the Race value corresponds to 7 or the Filipino race and does not allow values of ages beyond 999
plot(table(myDF$Age[(myDF$Race == 7) & (myDF$Age != 999)]))
# Out:
#       1       2       3       4       5       6       7      18      28      38
# 2241510  309504   18031   13297    8159     700   11074    6778    4711     623
#      48      58      68      78
#    4913     316    8737    2818
# [1] 11074
# plot without title

# %% [markdown]
# Using the data.table package in R we were able to read the CSV file. We then use the fread function to read in the csv file. With the table function we are able to see a portrayal of the Race. THen, with the sum function and the parameter of the value of Race being equal to 7 we are able to see all the summation of all the values equal to 7 (people in the Filipino Race) all summed up into the final value. With the plot function of the table with parameters of being Filipino whilst also removing any outlying values that are beyond the age of 999.

# %% [markdown]
# ## Question 2

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")
# Counts the number of times that a unique STORE_R value occurs where the rows of SPEND are negative
table(myDF$STORE_R[myDF$SPEND < 0])
# Out:
# CENTRAL    EAST   SOUTH    WEST
#    2750    3269    2675    3952

# %% [markdown]
# Using the data.table package in R we were able to read the CSV file. We then use the fread function to read in the csv file. With the table function we are able to present a set of data that takes from the STORE_R group of data only the values of SPEND that are less than 0 and eventually output the number of refunds for each store value without the use of a subset function.

# %% [markdown]
# ## Question 3

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/beer/reviews_sample.csv")
# Takes the last six values of a sorted table of the username column
tail(sort(table(myDF$username)), 6)
# Out:
#        jaydoc   Texasfan549         Sammy   kylehay2004 StonedTrippin
#          1489          1532          1591          1628          1630
#       acurtis
#          1646

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/beer/reviews_sample.csv")
# Calculates the average of the scores of which the username is equal to acurtis whilst removing scores attributed to missing values
mean(myDF$score[myDF$username == "acurtis"], na.rm = FALSE)
# Out:
# [1] 3.655802

# %% [markdown]
# Using the data.table package in R we were able to read the CSV file. We then use the fread function to read in the csv file. With the table function we are able to get the values that are the usernames and then using the sort function we are able to sort them in order from least to greatest, thus using the tail function with only 6 values we are able to get the 6 most popular values. Using the mean function we are able to get the average of all the scores of the usernames that are equal to acurtis whilst removing any na values with na.rm = FALSE.

# %% [markdown]
# ## Question 4

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/election/itcont1980.txt", quote="")
# Gets the NAME value of all the data values that are missing in the TRANSACTION_DT column
names(myDF) <- c("CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID")
myDF$NAME[is.na(myDF$TRANSACTION_DT)]
# Out:
# [1] "SCHECK, RICHARD HERBERT" "SCHECK, RICHARD HERBERT"
# [3] "SCHECK, RICHARD HERBERT" "SCHECK, RICHARD HERBERT"
# [5] "SCHECK, RICHARD HERBERT" "SCHECK, RICHARD HERBERT"
# [7] "CURCIO, BARBARA G"       "WOLFF, GARY W."
# [9] "WOLFF, GARY W."

# %% [markdown]
# Using the data.table package in R we were able to read the CSV file. We then use the fread function to read in the csv file. Using the name function we are able to rename the groups of data to our liking before using the is.na funciton to find out all the values from the TRANSACTION_DT column that have missing values. Then, with the NAME column we are able to attribute names to the missing values in the TRANSACTION_DT column.

# %% [markdown]
# ## Question 5

# %%
# This is the Starter Code
library(data.table)
# Because of the data.table library we are able to read the csv file into the myDF
myDF <- fread("/anvil/projects/tdm/data/flights/subset/1990.csv")
# Calculates the average departure delay in the myDF data frame in which the origin columns are set to EWR, JFK, and LGA while removing any NA values from the departure delay column
mean(myDF$DepDelay[myDF$Origin %in% c("EWR", "JFK", "LGA")], na.rm = TRUE)
# Out:
# [1] 9.400064

# %% [markdown]
# Using the data.table package in R we were able to read the CSV file. We then use the fread function to read in the csv file. The mean function allows us to take the average of all the departure delays while removing any missing values and only accepting values that have "EWR", "JFK", or "LGA in their O

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
